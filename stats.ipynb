# %%
import pandas as pd

df = pd.read_json("./data.jsonl", lines=True)

df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.set_index('timestamp')

# グラフを描画する
ax = df.plot(y=['done', 'need updating', 'missing'], kind='line', stacked=True)
